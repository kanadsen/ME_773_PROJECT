# %% [markdown]
# File to be called for necessary cleaning of data for a particular csv file

# %%
# Packages module Code
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score  #Scikit Learn
import os
import random
import argparse
import requests
from tqdm import tqdm  #tqdm is used for progress bar

# %%
#Global variable
raw_data=0

# %%
def read_file(s):
    return pd.read_csv(s, sep=',')
raw_data=read_file('file1.csv')
raw_data
# Out:
#        ENGINE_ID  CONDITION_ID  Cycle_Time  OpSet1  OpSet2  OpSet3  \
# 0              1             1           1  0.0023  0.0003   100.0
# 1              1             1           2 -0.0027 -0.0003   100.0
# 2              1             1           3  0.0003  0.0001   100.0
# 3              1             1           4  0.0042  0.0000   100.0
# 4              1             1           5  0.0014  0.0000   100.0
# ...          ...           ...         ...     ...     ...     ...
# 13091        100             1         194  0.0049  0.0000   100.0
# 13092        100             1         195 -0.0011 -0.0001   100.0
# 13093        100             1         196 -0.0006 -0.0003   100.0
# 13094        100             1         197 -0.0038  0.0001   100.0
# 13095        100             1         198  0.0013  0.0003   100.0
#
#        SensorMeasure1  SensorMeasure2  SensorMeasure3  SensorMeasure4  ...  \
# 0              518.67          643.02         1585.29         1398.21  ...
# 1              518.67          641.71         1588.45         1395.42  ...
# 2              518.67          642.46         1586.94         1401.34  ...
# 3              518.67          642.44         1584.12         1406.42  ...
# 4              518.67          642.51         1587.19         1401.92  ...
# ...               ...             ...             ...             ...  ...
# 13091          518.67          643.24         1599.45         1415.79  ...
# 13092          518.67          643.22         1595.69         1422.05  ...
# 13093          518.67          643.44         1593.15         1406.82  ...
# 13094          518.67          643.26         1594.99         1419.36  ...
# 13095          518.67          642.95         1601.62         1424.99  ...
#
#        SensorMeasure13  SensorMeasure14  SensorMeasure15  SensorMeasure16  \
# 0              2388.03          8125.55           8.4052             0.03
# 1              2388.06          8139.62           8.3803             0.03
# 2              2388.03          8130.10           8.4441             0.03
# 3              2388.05          8132.90           8.3917             0.03
# 4              2388.03          8129.54           8.4031             0.03
# ...                ...              ...              ...              ...
# 13091          2388.00          8213.28           8.4715             0.03
# 13092          2388.09          8210.85           8.4512             0.03
# 13093          2388.04          8217.24           8.4569             0.03
# 13094          2388.08          8220.48           8.4711             0.03
# 13095          2388.05          8214.64           8.4903             0.03
#
#        SensorMeasure17  SensorMeasure18  SensorMeasure19  SensorMeasure20  \
# 0                  392             2388            100.0            38.86
# 1                  393             2388            100.0            39.02
# 2                  393             2388            100.0            39.08
# 3                  391             2388            100.0            39.00
# 4                  390             2388            100.0            38.99
# ...                ...              ...              ...              ...
# 13091              394             2388            100.0            38.65
# 13092              395             2388            100.0            38.57
# 13093              395             2388            100.0            38.62
# 13094              395             2388            100.0            38.66
# 13095              396             2388            100.0            38.70
#
#        SensorMeasure21  RUL
# 0              23.3735   30
# 1              23.3916   29
# 2              23.4166   28
# 3              23.3737   27
# 4              23.4130   26
# ...                ...  ...
# 13091          23.1974    4
# 13092          23.2771    3
# 13093          23.2051    2
# 13094          23.2699    1
# 13095          23.1855    0
#
# [13096 rows x 28 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13096 entries, 0 to 13095
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ENGINE_ID        13096 non-null  int64
#  1   CONDITION_ID     13096 non-null  int64
#  2   Cycle_Time       13096 non-null  int64
#  3   OpSet1           13096 non-null  float64
#  4   OpSet2           13096 non-null  float64
#  5   OpSet3           13096 non-null  float64
#  6   SensorMeasure1   13096 non-null  float64
#  7   SensorMeasure2   13096 non-null  float64
#  8   SensorMeasure3   13096 non-null  float64
#  9   SensorMeasure4   13096 non-null  float64
#  10  SensorMeasure5   13096 non-null  float64
#  11  SensorMeasure6   13096 non-null  float64
#  12  SensorMeasure7   13096 non-null  float64
#  13  SensorMeasure8   13096 non-null  float64
#  14  SensorMeasure9   13096 non-null  float64
#  15  SensorMeasure10  13096 non-null  float64
#  16  SensorMeasure11  13096 non-null  float64
#  17  SensorMeasure12  13096 non-null  float64
#  18  SensorMeasure13  13096 non-null  float64
#  19  SensorMeasure14  13096 non-null  float64
#  20  SensorMeasure15  13096 non-null  float64
#  21  SensorMeasure16  13096 non-null  float64
#  22  SensorMeasure17  13096 non-null  int64
#  23  SensorMeasure18  13096 non-null  int64
#  24  SensorMeasure19  13096 non-null  float64
#  25  SensorMeasure20  13096 non-null  float64
#  26  SensorMeasure21  13096 non-null  float64
#  27  RUL              13096 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 2.8 MB
